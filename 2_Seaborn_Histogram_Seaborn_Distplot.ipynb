# %% [markdown]
# # Draw Seaborn Histogram / Seaborn Distplot

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
tips_df = sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(tips_df["size"])
plt.show()

# %%
sns.distplot(tips_df["tip"])
plt.show()

# %%
sns.distplot(tips_df["total_bill"])
plt.show()

# %%
"""sns.distplot(
    a,
    bins=None,
    hist=True,
    kde=True,
    rug=False,
    fit=None,
    hist_kws=None,
    kde_kws=None,
    rug_kws=None,
    fit_kws=None,
    color=None,
    vertical=False,
    norm_hist=False,
    axlabel=None,
    label=None,
    ax=None,
)"""
# Out:
# 'sns.distplot(\n    a,\n    bins=None,\n    hist=True,\n    kde=True,\n    rug=False,\n    fit=None,\n    hist_kws=None,\n    kde_kws=None,\n    rug_kws=None,\n    fit_kws=None,\n    color=None,\n    vertical=False,\n    norm_hist=False,\n    axlabel=None,\n    label=None,\n    ax=None,\n)'

# %%
sns.distplot(tips_df["total_bill"], bins = 10)
plt.show()

# %%
sns.distplot(tips_df["total_bill"], bins = 100)
plt.show()

# %%
sns.distplot(tips_df["total_bill"], hist = False)
plt.show()

# %%
sns.distplot(tips_df["total_bill"], hist = True)
plt.show()

# %%
sns.distplot(tips_df["total_bill"], kde = True)
plt.show()

# %%
sns.distplot(tips_df["total_bill"], kde = False)
plt.show()

# %%
sns.distplot(tips_df["total_bill"],rug = True)
plt.show()

# %%
sns.distplot(tips_df["total_bill"],rug = False)
plt.show()

# %%
sns.distplot(tips_df["total_bill"], fit = norm)
plt.show()

# %%
sns.distplot(tips_df["total_bill"], fit = norm, kde = False)
plt.show()

# %%
sns.distplot(tips_df["total_bill"], color = "r")
plt.show()

# %%
sns.distplot(tips_df["total_bill"], color = "b")
plt.show()

# %%
sns.distplot(tips_df["total_bill"], vertical = True)
plt.show()

# %%
sns.distplot(tips_df["total_bill"], norm_hist = True)
plt.show()

# %%
sns.distplot(tips_df["total_bill"], norm_hist = False)
plt.show()

# %%
sns.distplot(tips_df["total_bill"], axlabel = "Total Bill")
plt.show()

# %%
sns.distplot(tips_df["total_bill"], label = "Total Bill")
plt.show()

# %%
sns.distplot(tips_df["total_bill"], label = "Total Bill")

plt.legend()
plt.show()

# %%
sns.distplot(tips_df["total_bill"], label = "Total Bill")

plt.title("Histogrm Of Total Bill")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (16, 9))
sns.set()
sns.distplot(tips_df["total_bill"], label = "Total Bill")

plt.title("Histogrm Of Total Bill")
plt.legend()
plt.show()

# %%
tips_df.total_bill.sort_values()
# Out:
# 67      3.07
# 92      5.75
# 111     7.25
# 172     7.25
# 149     7.51
#        ...
# 182    45.35
# 156    48.17
# 59     48.27
# 212    48.33
# 170    50.81
# Name: total_bill, Length: 244, dtype: float64

# %%
bins = [1,5,10,15,20,25,30,35,40,45,50,55]

plt.figure(figsize = (16, 9))
sns.set()
sns.distplot(tips_df["total_bill"], bins = bins)

plt.xticks(bins)

plt.title("Histogrm Of Total Bill")
plt.show()

# %%
plt.figure(figsize = (16, 9))
sns.set()
sns.distplot(tips_df["total_bill"], hist_kws = {'color': '#DC143C'})

plt.show()

# %%
plt.figure(figsize = (16, 9))
sns.set()
sns.distplot(tips_df["total_bill"], hist_kws = {'color': '#DC143C', 'edgecolor': '#aaff00'})

plt.show()

# %%
plt.figure(figsize = (16, 9))
sns.set()
sns.distplot(tips_df["total_bill"], hist_kws = {'color': '#DC143C', 'edgecolor': '#aaff00', 
            'linewidth':5, 'linestyle':'--'})

plt.show()

# %%
plt.figure(figsize = (16, 9))
sns.set()
sns.distplot(tips_df["total_bill"], hist_kws = {'color': '#DC143C', 'edgecolor': '#aaff00', 
            'linewidth':5, 'linestyle':'--', 'alpha':0.9})

plt.show()

# %%
plt.figure(figsize = (16, 9))
sns.set()
sns.distplot(tips_df["total_bill"], 
             hist_kws = {'color': '#DC143C', 'edgecolor': '#aaff00', 
                        'linewidth':5, 'linestyle':'--', 'alpha':0.9}, 
            
            kde_kws = {'color': '#DC143C', 
                        'linewidth':5, 'linestyle':'--', 'alpha':0.9})

plt.show()

# %%
plt.figure(figsize = (16, 9))
sns.set()
sns.distplot(tips_df["total_bill"], 
             hist_kws = {'color': '#DC143C', 'edgecolor': '#aaff00', 
                        'linewidth':5, 'linestyle':'--', 'alpha':0.9}, 
            
            kde_kws = {'color': '#8e00ce', 
                        'linewidth':5, 'linestyle':'--', 'alpha':0.9})

plt.show()

# %%
plt.figure(figsize = (16, 9))
sns.set()
sns.distplot(tips_df["total_bill"], 
             hist_kws = {'color': '#DC143C', 'edgecolor': '#aaff00', 
                        'linewidth':5, 'linestyle':'--', 'alpha':0.9}, 
            
            kde_kws = {'color': '#8e00ce', 
                        'linewidth':8, 'linestyle':'--', 'alpha':0.9})

plt.show()

# %%
plt.figure(figsize = (16, 9))
sns.set()
sns.distplot(tips_df["total_bill"], 
             hist_kws = {'color': '#DC143C', 'edgecolor': '#aaff00', 
                        'linewidth':5, 'linestyle':'--', 'alpha':0.9}, 
            
            kde_kws = {'color': '#8e00ce', 
                        'linewidth':8, 'linestyle':'--', 'alpha':0.9}, 
            rug = True, 
            rug_kws = {'color': '#DC143C', 'edgecolor': '#aaff00', 
                        'linewidth':5, 'linestyle':'--', 'alpha':0.9})

plt.show()

# %%
plt.figure(figsize = (16, 9))
sns.set()
sns.distplot(tips_df["total_bill"], 
             hist_kws = {'color': '#DC143C', 'edgecolor': '#aaff00', 
                        'linewidth':5, 'linestyle':'--', 'alpha':0.9}, 
            
            kde_kws = {'color': '#8e00ce', 
                        'linewidth':8, 'linestyle':'--', 'alpha':0.9}, 
            rug = True, 
            rug_kws = {'color': '#0426d0', 'edgecolor': '#00dbff', 
                        'linewidth':5, 'linestyle':'--', 'alpha':0.9})

plt.show()

# %%
plt.figure(figsize = (16, 9))
sns.set()
sns.distplot(tips_df["total_bill"], 
             hist_kws = {'color': '#DC143C', 'edgecolor': '#aaff00', 
                        'linewidth':5, 'linestyle':'--', 'alpha':0.9}, 
            
            kde_kws = {'color': '#8e00ce', 
                        'linewidth':8, 'linestyle':'--', 'alpha':0.9}, 
            rug = True, 
            rug_kws = {'color': '#0426d0', 'edgecolor': '#00dbff', 
                        'linewidth':3, 'linestyle':'--', 'alpha':0.9})

plt.show()

# %%
plt.figure(figsize = (16, 9))
sns.set()
sns.distplot(tips_df["total_bill"], 
             hist_kws = {'color': '#DC143C', 'edgecolor': '#aaff00', 
                        'linewidth':5, 'linestyle':'--', 'alpha':0.9}, 
            
            kde = False,
            fit = norm,
            fit_kws = {'color': '#8e00ce', 
                        'linewidth':11, 'linestyle':'--', 'alpha':0.4},
            rug = True, 
            rug_kws = {'color': '#0426d0', 'edgecolor': '#00dbff', 
                        'linewidth':5, 'linestyle':'--', 'alpha':0.9})

plt.show()

# %%
plt.figure(figsize = (16, 9))
sns.set()
sns.distplot(tips_df["total_bill"], 
             hist_kws = {'color': '#DC143C', 'edgecolor': '#aaff00', 
                        'linewidth':5, 'linestyle':'--', 'alpha':0.9}, 
            
            kde = False,
            fit = norm,
            fit_kws = {'color': '#8e00ce', 
                        'linewidth':11, 'linestyle':'--', 'alpha':0.4},
            rug = True, 
            rug_kws = {'color': '#0426d0', 'edgecolor': '#00dbff', 
                        'linewidth':5, 'linestyle':'--', 'alpha':0.9}, 
            label = "TB")

plt.title("Histogram Of Restaurent Total Bill", fontsize = 20)
plt.xlabel("Total Bill", fontsize = 15)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (16, 9))
sns.distplot(tips_df["total_bill"], bins = 9, label = "total_bill")
sns.distplot(tips_df["tip"], bins = 9, label = "tip")
sns.distplot(tips_df["size"], bins = 9, label = "size")

plt.legend()
plt.show()
